# %%
import numpy as np

# %%
import pandas as pd

# %%
df.shape
# Out:
# (198, 33)

# %%
column_names = [
    "ID", "Outcome", "Time",  # First three columns
    "Radius_mean", "Texture_mean", "Perimeter_mean", "Area_mean", "Smoothness_mean", "Compactness_mean",
    "Concavity_mean", "Concave_points_mean", "Symmetry_mean", "Fractal_dimension_mean",
    
    "Radius_se", "Texture_se", "Perimeter_se", "Area_se", "Smoothness_se", "Compactness_se",
    "Concavity_se", "Concave_points_se", "Symmetry_se", "Fractal_dimension_se",

    "Radius_worst", "Texture_worst", "Perimeter_worst", "Area_worst", "Smoothness_worst", "Compactness_worst",
    "Concavity_worst", "Concave_points_worst", "Symmetry_worst", "Fractal_dimension_worst",

    "Tumor_size",  # 34th attribute
    "Lymph_node_status"  # 35th attribute (has missing values)
]

# %%
df = pd.read_csv("wpbc.data", header=None, names=column_names)

# %%
df
# Out:
#          ID Outcome  Time  Radius_mean  Texture_mean  Perimeter_mean  \
# 0    119513       N    31        18.02         27.60          117.50
# 1      8423       N    61        17.99         10.38          122.80
# 2    842517       N   116        21.37         17.44          137.50
# 3    843483       N   123        11.42         20.38           77.58
# 4    843584       R    27        20.29         14.34          135.10
# ..      ...     ...   ...          ...           ...             ...
# 193  942640       N    10        22.52         21.92          146.90
# 194  943471       N     8        15.44         31.18          101.00
# 195   94547       N    12        17.17         29.19          110.00
# 196  947204       R     3        21.42         22.84          145.00
# 197  947489       N     6        16.70         28.13          110.30
#
#      Area_mean  Smoothness_mean  Compactness_mean  Concavity_mean  ...  \
# ...

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# N    151
# R     47
# Name: count, dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## There is no null value in this datast

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
coder = LabelEncoder()

# %%
df['Outcome']=coder.fit_transform(df['Outcome'])

# %%
df
# Out:
#          ID  Outcome  Time  Radius_mean  Texture_mean  Perimeter_mean  \
# 0    119513        0    31        18.02         27.60          117.50
# 1      8423        0    61        17.99         10.38          122.80
# 2    842517        0   116        21.37         17.44          137.50
# 3    843483        0   123        11.42         20.38           77.58
# 4    843584        1    27        20.29         14.34          135.10
# ..      ...      ...   ...          ...           ...             ...
# 193  942640        0    10        22.52         21.92          146.90
# 194  943471        0     8        15.44         31.18          101.00
# 195   94547        0    12        17.17         29.19          110.00
# 196  947204        1     3        21.42         22.84          145.00
# 197  947489        0     6        16.70         28.13          110.30
#
#      Area_mean  Smoothness_mean  Compactness_mean  Concavity_mean  ...  \
# ...

# %%
df
# Out:
#          ID  Outcome  Time  Radius_mean  Texture_mean  Perimeter_mean  \
# 0    119513        0    31        18.02         27.60          117.50
# 1      8423        0    61        17.99         10.38          122.80
# 2    842517        0   116        21.37         17.44          137.50
# 3    843483        0   123        11.42         20.38           77.58
# 4    843584        1    27        20.29         14.34          135.10
# ..      ...      ...   ...          ...           ...             ...
# 193  942640        0    10        22.52         21.92          146.90
# 194  943471        0     8        15.44         31.18          101.00
# 195   94547        0    12        17.17         29.19          110.00
# 196  947204        1     3        21.42         22.84          145.00
# 197  947489        0     6        16.70         28.13          110.30
#
#      Area_mean  Smoothness_mean  Compactness_mean  Concavity_mean  ...  \
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # Handling Missing Values

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df
# Out:
#          ID  Outcome  Time  Radius_mean  Texture_mean  Perimeter_mean  \
# 0    119513        0    31        18.02         27.60          117.50
# 1      8423        0    61        17.99         10.38          122.80
# 2    842517        0   116        21.37         17.44          137.50
# 3    843483        0   123        11.42         20.38           77.58
# 4    843584        1    27        20.29         14.34          135.10
# ..      ...      ...   ...          ...           ...             ...
# 193  942640        0    10        22.52         21.92          146.90
# 194  943471        0     8        15.44         31.18          101.00
# 195   94547        0    12        17.17         29.19          110.00
# 196  947204        1     3        21.42         22.84          145.00
# 197  947489        0     6        16.70         28.13          110.30
#
#      Area_mean  Smoothness_mean  Compactness_mean  Concavity_mean  ...  \
# ...
